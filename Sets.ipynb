# %%
## sets
new_sets = {1,2,3}
print(type(new_sets))
# Out:
# <class 'set'>

# %%
new_sets.add(7)
print(new_sets)
# Out:
# {1, 2, 3, 7}

# %%
new_sets.discard(6)

# %%
new_sets.remove(6)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 new_sets.remove(6)
#
# KeyError: 6

# %%
new_sets.pop()  ## removes element from begining and returns the element
print(new_sets)
# Out:
# {7}

# %%
## Counting unique words in text

text = 'In this tutorial we are discussing about sets we'

words = text.split()

print(words)

## Convert list of words to sets to get unique words

Unique_words = set(words)

print(Unique_words)
# Out:
# ['In', 'this', 'tutorial', 'we', 'are', 'discussing', 'about', 'sets', 'we']
# {'In', 'we', 'discussing', 'are', 'tutorial', 'this', 'about', 'sets'}
