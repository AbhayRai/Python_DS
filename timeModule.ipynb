# %% [markdown]
# ## Time module

# %%
import time

# %%
t1 = time.time()

# %%
'Abhay' + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 'Abhay' + 5
#
# TypeError: can only concatenate str (not "int") to str
