# %%
## Filter 
numbers = [1,2,3,4,5,6]
greaterThanThree = list(filter(lambda x:x>3,numbers))
print(greaterThanThree)
# Out:
# [4, 5, 6]

# %%
num = [1,2,3,4,5,6,7,8,9]

## multiple condition
evenGreaterThanThree = list(filter(lambda x:x>4 and x%2==0,num))

print(evenGreaterThanThree)
# Out:
# [6, 8]
