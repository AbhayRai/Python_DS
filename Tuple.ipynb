# %%
## Tuples

## creating a tuple

new_tuple = ('Abhay','Rai')
print(type(new_tuple))
# Out:
# <class 'tuple'>

# %%
new_tuple.count('Abhay')
# Out:
# 1

# %%
new_tuple.index('Abhay')
# Out:
# 0

# %%
'''
Tuple packing and unpacking in Python allow you to conveniently assign values to a tuple (packing) and then extract those values into individual variables (unpacking).

Tuple Packing
Tuple packing is the process of combining multiple values into a single tuple. For example, you can pack values without explicitly using parentheses:

'''

# Tuple packing
packed_tuple = 1, 2, 3, 'Abhay'
print(packed_tuple)  # Output: (1, 2, 3, 'Abhay')
# Out:
# (1, 2, 3, 'Abhay')

# %%
## tuple unpacking

a,*b,c = Old_tuple
print(a)
print(b)
print(c)
# Out:
# 1
# [2, 3]
# 4

# %%
## Slicing

sample_tuple = (0, 1, 2, 3, 4, 5, 6)
print(sample_tuple[2:5])    # Output: (2, 3, 4)
print(sample_tuple[::2])    # Output: (0, 2, 4, 6)
# Out:
# (2, 3, 4)
# (0, 2, 4, 6)

# %%
'''
7. When to Use Tuples

Immutable Data:
Use tuples when you need a collection of values that should not change throughout the program.

Dictionary Keys:
Tuples can be used as keys in dictionaries because they are immutable.

Function Returns:
Tuples are commonly used to return multiple values from a function.
'''
