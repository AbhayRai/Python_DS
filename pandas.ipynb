# %%
# !pip install pandas
import pandas as pd
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    --------- ------------------------------ 2.6/11.0 MB 16.7 MB/s eta 0:00:01
#    --------------------- ------------------ 6.0/11.0 MB 16.8 MB/s eta 0:00:01
#    --------------------------------- ------ 9.2/11.0 MB 15.8 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 14.9 MB/s eta 0:00:00
# ...

# %%
data = [1,2,3]
s = pd.Series(data)
print(type(s))
print(s)
# Out:
# <class 'pandas.core.series.Series'>
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
new_data = [2,3,4,5]
xS= pd.Series(new_data,index=["a","b","c","d"])
print(xS)
# Out:
# a    2
# b    3
# c    4
# d    5
# dtype: int64

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 35]
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
df["Age"] + 5
# Out:
# 0    30
# 1    35
# 2    40
# Name: Age, dtype: int64
